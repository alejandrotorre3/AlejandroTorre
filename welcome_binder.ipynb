# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
print('hola')

# %%
# %ls
# Out:
# 07_02_pie_box_scatter_bubble.ipynb  README.md         session_01/
# Canada.xlsx                         requierementsEXL  welcome_binder.ipynb
# datasets/                           requirements.txt
# nhanes_2015_2016.csv                runtime.txt

# %%
#magic

# %%
nombre = 'my Name'
nombre
# Out:
# 'my Name'

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
import numpy as np

# %%
N = 50
x = np.random.rand(N)
x
# Out:
# array([0.12752493, 0.91826203, 0.37110353, 0.26874507, 0.28330544,
#        0.99098954, 0.45933905, 0.94173848, 0.46883555, 0.50298415,
#        0.83853753, 0.94726682, 0.22975705, 0.84118208, 0.45692926,
#        0.86857345, 0.99737002, 0.20360303, 0.140008  , 0.35985773,
#        0.2581556 , 0.41833527, 0.18953404, 0.56575389, 0.44532988,
#        0.29348754, 0.41088887, 0.18539674, 0.16963995, 0.53856903,
#        0.8687025 , 0.6770825 , 0.01092612, 0.47180987, 0.87370004,
#        0.78336564, 0.2999147 , 0.95773172, 0.32790168, 0.0772015 ,
#        0.2664128 , 0.57655454, 0.59117825, 0.87161759, 0.72533444,
#        0.34071983, 0.04425466, 0.36072123, 0.31180857, 0.06668134])

# %% [markdown]
# #Tipos de data en Python

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(nombre)
# Out:
# str

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(-3)
# Out:
# int

# %%
type('1:3')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
suma = sum(numbers)
suma
# Out:
# 15

# %%
length_numbers = len(numbers)
length_numbers
# Out:
# 5

# %%
type(numbers)
# Out:
# list

# %%
promedio = suma/length_numbers
promedio
# Out:
# 3.0

# %%
# 60*10^2(-2)= 60*(1/100) = 60*0.01 = 0.6
60*10**-2
# Out:
# 0.6

# %%
type(bool('yes'))
# Out:
# bool

# %%
type('yes')
# Out:
# str

# %%
type(6<5)
# Out:
# bool

# %%
a_list = [True, 6<5, 1==3, None is None, 2, 'Name']
a_list
# Out:
# [True, False, False, True, 2, 'Name']

# %%
x = 5
y = 6
if x<y:
    print('{} es menor que {}'.format(x, y))
else: 
        print('{} es mayor que {}'.format(x,y))
# Out:
# 5 es menor que 6
