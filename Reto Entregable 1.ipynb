# %% [markdown]
# Visualizacion de Datos

# %%
## Empece importando las librerias que tengo que utilizar para el desarrollo de mi reto

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Quise confirmar que mi base de datos que importe estaba en el mismo path que estaba trabajando.

# %%
# %ls
# Out:
#  07_02_pie_box_scatter_bubble.ipynb   requierementsEXL
#  Canada.xlsx                          requirements.txt
#  datasets/                           'Reto Entregable 1.ipynb'
#  estadistica-descriptiva.ipynb        runtime.txt
#  movie_metadata.csv                   session_01/
#  nhanes_2015_2016.csv                 welcome_binder.ipynb
#  README.md

# %%
#Para poder abrir la base de datos tengo que utilizar panda para abrirlo dentro de un dataframe

# %%
df = pd.read_csv("movie_metadata.csv")

# %%
#Ya al asignar que tu dataframe sea tu base de datos abri el dataframe que me muestra los datos

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#Note que en mi dataframe habian columnas que no influyen el analisis que voy a realizar por ende lo borre

# %%
df = pd.read_csv("movie_metadata.csv")

df.drop("color",
        axis=1,inplace=True,)
         
df.drop("duration",
        axis=1,inplace=True,)

df.drop("gross",
        axis=1,inplace=True,)

df.drop("movie_imdb_link",
        axis=1,inplace=True,)

df.drop("aspect_ratio",
        axis=1,inplace=True,)    

df.drop( "facenumber_in_poster",
        axis=1,inplace=True) 
df

df.head()
# Out:
#        director_name  num_critic_for_reviews  director_facebook_likes  \
# 0      James Cameron                   723.0                      0.0
# 1     Gore Verbinski                   302.0                    563.0
# 2         Sam Mendes                   602.0                      0.0
# 3  Christopher Nolan                   813.0                  22000.0
# 4        Doug Walker                     NaN                    131.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# ...

# %% [markdown]
# La variable de interes de mi base de datos es "imdb_score" lo cual se identifica como la valoracion de gusto de la pelicula en este sitio en especifico. Es el sitio mas utilizado para hacer el rank de peliculas que hayan salido por lo cual le dan la importancia. Mi proposito con esta base de datos es descubrir la importancia de las variables "num_critic_for_reviews", "budget", "num_voted_users", "actor_1_name", y como impactan el "imbd_score".
